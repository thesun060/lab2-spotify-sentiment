# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-474fcb5c-e627-4eda-8466-4380dba79c12" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-474fcb5c-e627-4eda-8466-4380dba79c12">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

df = pd.read_csv("ulasan_com.spotify.music.csv")
df.head()
# Out:
#          Nama User                                             Ulasan  Rating  \
# 0  Pengguna Google                            suka banget sama ni app       5
# 1  Pengguna Google                                               bgus       5
# 2  Pengguna Google  ga bisa denger lagu JKT48 lagi gara² selalu di...       1
# 3  Pengguna Google            lagunya bagus banget buat ngapa ngapain       5
# 4  Pengguna Google  kenapa sih, aku cuman bisa main 5 lagu doang? ...       1
#
#                Tanggal  Likes   Versi App
# 0  2025-12-31 17:27:52      0  9.1.6.1145
# 1  2025-12-31 17:25:25      0  9.1.6.1145
# 2  2025-12-31 16:39:10      0  9.1.6.1145
# 3  2025-12-31 16:35:54      0  9.1.6.1145
# 4  2025-12-31 16:29:15      0  9.1.6.1145

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 6 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   Nama User  100000 non-null  object
#  1   Ulasan     100000 non-null  object
#  2   Rating     100000 non-null  int64
#  3   Tanggal    100000 non-null  object
#  4   Likes      100000 non-null  int64
#  5   Versi App  72298 non-null   object
# dtypes: int64(2), object(4)
# memory usage: 4.6+ MB

# %%
df.shape
# Out:
# (100000, 6)
